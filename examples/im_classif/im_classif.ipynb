# %% [markdown]
# ## Image Classification Example
#
# This notebook imports the [`im_classif.py`](https://github.com/forman/dectree/blob/master/examples/im_classif.py) module which has been generated from the decision tree in [`im_classif.yml`](https://github.com/forman/dectree/blob/master/examples/im_classif.yml) using the following command:
#
# ```bash
# $ dectree examples/im_classif/im_classif.yml
# ```

# %%
import im_classif

# %%
from PIL import Image
import numpy as np

# %% [markdown]
# ### Import a test image

# %%
im = Image.open('test_im.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x576 at 0x219883E5D68>

# %% [markdown]
# ### Extract the R,G,B channels as Numpy arrays of type `float64`

# %%
red = np.array(im.getdata(band=0), dtype=np.float64)
green = np.array(im.getdata(band=1), dtype=np.float64)
blue = np.array(im.getdata(band=2), dtype=np.float64)

# %% [markdown]
# ### Classification input

# %%
inputs = im_classif.Inputs()
inputs.red = red
inputs.green = green
inputs.blue = blue

# %% [markdown]
# ### Classification output

# %%
outputs = im_classif.Outputs()

# %% [markdown]
# ### Classify

# %%
im_classif.apply_rules(inputs, outputs)

# %% [markdown]
# ### Display outputs

# %%
def truth_to_image(truth):
    im_data = np.array(255 * truth, dtype=np.uint8).reshape(im.height, im.width)
    return Image.fromarray(im_data)

# %%
truth_to_image(outputs.cloudy)
# Out:
# <PIL.Image.Image image mode=L size=1024x576 at 0x2198B5C4CF8>

# %%
truth_to_image(outputs.grey)
# Out:
# <PIL.Image.Image image mode=L size=1024x576 at 0x2198B578E10>

# %%
truth_to_image(outputs.yellow)
# Out:
# <PIL.Image.Image image mode=L size=1024x576 at 0x2198B5777F0>

# %%
truth_to_image(outputs.dark_red)
# Out:
# <PIL.Image.Image image mode=L size=1024x576 at 0x2198B5C4D30>

# %%
truth_to_image(outputs.dark)
# Out:
# <PIL.Image.Image image mode=L size=1024x576 at 0x2198B5C4128>

# %%
truth_to_image(outputs.not_dark)
# Out:
# <PIL.Image.Image image mode=L size=1024x576 at 0x2198B5789E8>
